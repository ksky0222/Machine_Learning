# %% [markdown]
# # [SWCON253] Machine Learning
# Teaching Assistant: Hyundong Cho (gusehd1113@khu.ac.kr)
#
# Professor: Jinwoo Choi (jinwoochoi@khu.ac.kr)

# %% [markdown]
# ---

# %% [markdown]
# # P3:  Deep Learning Framwork: Pytorch를 이용하여 MLP 구현 (10점)
#
# ### 학습목표
# - pytorch를 사용하여 구현된 MLP 구조를 이해하고 수정할수 있다.
# - Fashinon-MNIST 문제를 스스로 해결하면서 딥러닝 학습과정을 이해하고 하이퍼파라미터를 튜닝을 할 수 있다.
#
# ### 실습내용
# pytorch를 사용하여 구현 되어 있는 MLP를 통해 Fashion-MNIST 데이터셋을 분류하는 classfier를 학습합니다.
#
# 실습은 다음 순서로 진행됩니다.
# - 1) Fashon-MNIST 데이터셋 설명
# - 2) Data loading
# - 3) Multilayer Perceptron Model
# - 4) Training
# - 5) Evaluation
# - 6) Discussion
#
# 아래 코드에는 1개의 퍼셉트론은 이용한 MLP 모델이 정의 되어 있습니다. <br>
# 실습을 시작하기전에 이 노트북 파일을 읽고 모든 셀을 실행하여 올바르게 작동하는지 확인하세요.<br>
# 이후에 아키텍쳐를 적절하게 변경하여 최고의 성능이 나오도록 수정해 보세요.
#
# **1. 다음은 변경 가능한 부분입니다.**
# - activation 함수 (logistic sigmoid, tanh, relu, leaky relu, ...)
# - learning rate
# - hidden layers 갯수
# - epochs
# - batch size
# - 각 hidden layer의 neuron 개수
#
# **2. 다음 사항은 변경하지 마세요.**
# - 가중치 초기화 방법
# - 랜덤시드
# - 최적화 방법, 학습 방법
#
# **3. layer를 추가하여 2개 이상의 hidden layer를 구성할 수 있게 구현하세요.**
#
# **4. 수정가능한 셀은 아래 주석으로 확실하게 하이라이트되어 표시되어 있습니다.**
#
# ```
# ############################################################
# ################## 변경 가능한 셀 ##########################
# ############################################################
# ```
#
# ### 점수
# **Test set 기준 (hidden layer 수를 2개 이상으로 설정하지 않으면 0점)**
#
# - 정확도 85% 이상 2점
# - 정확도 86% 이상 4점
# - 정확도 87% 이상 6점
# - 정확도 88% 이상 8점
#
# **Discussion**
# - Discussion 점수: 2점
#
# `.ipynb 파일과 함께 .html 파일 (File -> export as -> HTML)도 함께 제출하세요. 하나만 제출할시 감점이 있습니다.`

# %%
import torch
import os
import numpy as np
import time
import random
from PIL import Image
from torch.utils.data import Dataset
from torchvision import transforms
from torch.utils.data import DataLoader
import torch.nn.functional as F
# Document: https://pytorch.org/docs/stable/nn.functional.html
import matplotlib.pyplot as plt
# Document: https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.html
# %matplotlib inline

# %%
# 이 부분은 절대 변경하지 마세요.

RANDOM_SEED = 123
DEVICE = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# ## 1) Dataset 설명

# %% [markdown]
# 이 데이터셋은 기존의 MNIST와 비슷하게 10개의 클래스로 이루어진 데이터셋입니다. 또한 흑백의 28x28크기, 60k개의 학습용 이미지와 10k개의 테스트용 이미지로 구성 되어 있는것과 같이 MNIST와 대부분 비슷한 구조로 이뤄져 있습니다.
#
# 아래는 데이터셋의 샘플 이미지 입니다.
#
# ![](https://github.com/zalandoresearch/fashion-mnist/raw/master/doc/img/fashion-mnist-sprite.png)
#
# 출처: https://github.com/zalandoresearch/fashion-mnist)

# %% [markdown]
# 데이터셋의 10개의 클래스는 다음과 같습니다.
#
#
# | Label | Description |
# | --- | --- |
# | 0 | T-shirt/top |
# | 1 | Trouser |
# | 2 | Pullover |
# | 3 | Dress |
# | 4 | Coat |
# | 5 | Sandal |
# | 6 | Shirt |
# | 7 | Sneaker |
# | 8 | Bag |
# | 9 | Ankle boot |

# %% [markdown]
# ## 2) Dataset Loader

# %%
import torch
from PIL import Image
from torchvision.datasets import FashionMNIST
from torchvision import transforms
from torch.utils.data import DataLoader

import os

# %%
# Train 데이터 로딩시 이미지 데이터 전처리를 Transforms를 통해 할 수 있습니다.
# ToTensor는 PIL 형태의 이미지나 ndarray 를 PyTorch 가 이해할 수 있는 tensor 자료형으로 바꾸어 주는 역할을 하며
# Random Flip, Random Crop 등을 사용하여 Data augmentation을 수행하고 이를 통해 좋은 성능을 얻을 수 있습니다.
# 하지만, 이번 실습에서는 사용하지 않습니다.
# Document: https://pytorch.org/vision/stable/transforms.html
custom_train_transform = transforms.Compose([  
                                             transforms.ToTensor(),
                                             transforms.Normalize(mean=(0.5,), std=(0.5,))
])

# %%
# Test 데이터 로딩시 데이터 Transform
# Testset의 Trainsform은 Training set 과 다르게 랜덤하게 변경되면 안됩니다. Testset에 대한 정확한 결과를 가져와야 하기 때문입니다.
# 이번 실습에서는 사용하지 않습니다.
custom_test_transform = transforms.Compose([
                                             transforms.ToTensor(),
                                             transforms.Normalize(mean=(0.5,), std=(0.5,))
])

# %%
############################################################
################## 변경 가능한 셀 ##########################
############################################################

# BATCH_SIZE = 60000을 사용하면 Full-Batch 학습
# BATCH_SIZE = 1을 사용하면 Online 학습
# BATCH_SIZE = N (1 < N < 60000) 을 사용하면 Mini-batch 학습
BATCH_SIZE = 128

# %%
train_dataset = FashionMNIST(".", train=True, download=True, transform=custom_train_transform)

train_loader = DataLoader(dataset=train_dataset,
                          batch_size=BATCH_SIZE,
                          shuffle=True,
                          drop_last=True,
                          num_workers=2)


test_dataset = FashionMNIST(".", train=False, download=True, transform=custom_test_transform)

test_loader = DataLoader(dataset=test_dataset,
                         batch_size=BATCH_SIZE,
                         shuffle=False,
                         num_workers=2)

# %% [markdown]
# 아래 셀은 데이터셋이 잘 Load 되었는지 확인하는 테스트용 코드입니다.
#
# 특히, Label data의 경우 One-hot vector encoding 되기 전의 형태의 class label 정보입니다.

# %%
num_epochs = 1
for epoch in range(num_epochs):

    for batch_idx, (x, y) in enumerate(train_loader):
        
        print('Epoch:', epoch+1, end='')
        print(' | Batch index:', batch_idx, end='')
        print(' | Batch size:', y.size()[0])
        
        x = x.to(DEVICE)
        y = y.to(DEVICE)
        print(f'Image data shape: \t {x.shape}')
        print(f'Label data shape: \t {y.shape}')
        print(y)
        break
# Out:
# Epoch: 1 | Batch index: 0 | Batch size: 128
# Image data shape: 	 torch.Size([128, 1, 28, 28])
# Label data shape: 	 torch.Size([128])
# tensor([3, 3, 4, 0, 8, 6, 9, 8, 8, 2, 3, 1, 3, 3, 0, 5, 4, 8, 3, 0, 9, 5, 3, 9,
#         9, 5, 4, 1, 8, 7, 9, 8, 7, 4, 8, 2, 6, 0, 6, 7, 6, 0, 9, 7, 5, 0, 1, 3,
#         3, 9, 3, 2, 5, 3, 0, 7, 0, 3, 0, 4, 3, 8, 8, 7, 7, 0, 1, 0, 9, 9, 8, 7,
#         1, 0, 5, 1, 4, 3, 9, 1, 7, 3, 2, 7, 3, 9, 1, 3, 6, 9, 1, 8, 6, 7, 9, 9,
#         2, 1, 2, 1, 8, 4, 4, 2, 9, 1, 9, 2, 0, 3, 2, 9, 9, 6, 2, 9, 8, 2, 5, 3,
#         7, 1, 3, 9, 4, 3, 3, 6])

# %% [markdown]
# ## 3) Multilayer Perceptron Model
#
# 아래 셀은 MLP모델을 정의하는 부분입니다. 이 과제에서 메인 부분입니다.<br>
# 현재는 Hidden layer 하나로 구성되어 있습니다.<br>
# **Hidden layer이 2개**가 되도록 변경하세요.(**init 정의, output layer 의 입력**도 수정해야 합니다.)<br>
# 필요에 따라 3개 이상으로 늘려도 됩니다.

# %%
############################################################
################## 변경 가능한 셀 ##########################
############################################################

class MLP(torch.nn.Module):
    
    # <your code> to define function
    # 힌트: def __init__(self, num_features, num_hidden_1, num_hidden_2, num_classes):
    def __init__(self, num_features, num_hidden_1, num_hidden_2, num_classes):
        super(MLP, self).__init__()
        
        self.num_classes = num_classes # 10
        self.linear_1 = torch.nn.Linear(num_features, num_hidden_1)
        # <your code> to add layer
        self.linear_2 = torch.nn.Linear(num_hidden_1, num_hidden_2)
        # self.linear_3 = torch.nn.Linear(num_hidden_2, num_hidden_3)
        self.linear_out = torch.nn.Linear(num_hidden_2, num_classes)
        
        
        # Multi-class classification 문제를 풀기 위해 Softmax 함수를 사용합니다.
        self.softmax = torch.nn.Softmax(dim=-1)
        
    def forward(self, x):
        
        ### activation 함수 변경 가능
        ### 레이어간의 연결 추가, 변경
        out1 = self.linear_1(x)
        out1 = F.relu(out1)
        out2 = self.linear_2(out1)
        out2 = F.relu(out2)
        # out3 = self.linear_3(out2)
        # out3 = torch.relu(out3)
        # <your code> to set the layer and the activation function
        
        logits = self.linear_out(out2)
        
        # Multi-class classification 문제를 풀기 위해 Softmax 함수를 사용합니다.
        # 다만, 이후 사용할 F.cross_entropy() 함수 내부에 Softmax가 이미 구현되어 있기 때문에
        # Loss function 계산 시에는 self.softmax()를 통과하기 전의 logits 값을 이용하게 됩니다.
        probas = self.softmax(logits)
        return logits, probas

# random seed는 무작위 가중치 초기화가 항상 같도록 해줍니다.
# 초기화된 가중치에 따라 같은 네트워크도 서로 다른 성능을 낼 수 있어서 
# 실제 사용시에는 좋은 성능을 얻기 위해 여러가지 무작위 가중치를 시도해 볼 수 있습니다.
# 그러나 이 과제에서는 변경하지 않습니다.
random.seed(RANDOM_SEED)
torch.manual_seed(RANDOM_SEED)

# %% [markdown]
# ## 4) Training

# %% [markdown]
# **다중 클래스 분류 모델을 위한 Cross Entropy Loss 사용 시 주의점**
#
# - 모델의 출력인 logits, probas의 차원은 [BATCH_SIZE, num_classes] 형태지만, 정답 Label인 targets 변수의 차원은 [BATCH_SIZE] 입니다. (ex, [1, 3, 2, 4, 9, ..., 3])
#
#
# - 일반적으로 Cross Entropy Loss를 계산하기 위해서는 targets에 one-hot vector encoding을 수행해주어야 하지만, F.cross_entropy() 함수는 이를 내부적으로 수행해줍니다.
#
#
# - 또한, F.cross_entropy() 함수 내부적으로 softmax 함수를 이용하기 때문에, 모델의 출력 중 probas 값이 아닌 logits 값 (softmax를 통과하기 이전 값)을 이용하여 Loss function을 계산합니다.
#
#
# - 구현 상세는 pytorch documents에서 확인할 수 있습니다. (https://pytorch.org/docs/stable/generated/torch.nn.functional.cross_entropy.html#torch.nn.functional.cross_entropy)

# %%
############################################################
################## 변경 가능한 셀 ##########################
############################################################

### num_hidden_1 변경 가능
### hidden layer 를 추가하였기 때문에 이부분도 알맞게 수정해야 합니다.
model = MLP(num_features=28*28,
            num_hidden_1=512,
            num_hidden_2=512,
            num_classes=10)

model = model.to(DEVICE)

### Optimizer는 가중치를 업데이트하는 방법을 바꾸어 더 빠르게 좋은 성능을 낼 수 있도록합니다.
### 이 과제에서는 Optimizer를 변경하지 않습니다. 
### 그러나 Learning Rate(lr)는 변경이 가능합니다.
optimizer = torch.optim.SGD(model.parameters(), lr=0.1)

### EPOCHS 수 변경 가능
NUM_EPOCHS = 30

### 아래는 변경 하지 마세요!
def compute_accuracy_and_loss(model, data_loader, device):
    correct_pred, num_examples = 0, 0
    cross_entropy = 0.
    for i, (features, targets) in enumerate(data_loader):
            
        features = features.view(-1, 28*28).to(device)
        targets = targets.to(device)

        logits, probas = model(features)
        
        # Loss 계산 시에는 logits 이용
        cross_entropy += F.cross_entropy(logits, targets).item()
        
        # 추론 시에는 probas 이용
        _, predicted_labels = torch.max(probas, 1)
        num_examples += targets.size(0)
        correct_pred += (predicted_labels == targets).sum()
    return correct_pred.cpu().float()/num_examples * 100, cross_entropy/num_examples


start_time = time.time()
train_acc_lst, test_acc_lst = [], []
train_loss_lst, test_loss_lst = [], []

for epoch in range(NUM_EPOCHS):
    
    model.train()
    
    for batch_idx, (features, targets) in enumerate(train_loader):
    
        ### PREPARE MINIBATCH
        features = features.view(-1, 28*28).to(DEVICE)
        targets = targets.to(DEVICE)
            
        ### FORWARD AND BACK PROP
        logits, probas = model(features)
        cost = F.cross_entropy(logits, targets)
        optimizer.zero_grad()
        
        cost.backward()
        
        ### UPDATE MODEL PARAMETERS
        optimizer.step()
        
        ### LOGGING
        if not batch_idx % 40:
            print (f'Epoch: {epoch+1:03d}/{NUM_EPOCHS:03d} | '
                   f'Batch {batch_idx:03d}/{len(train_loader):03d} |' 
                   f' Cost: {cost:.4f}')

    # no need to build the computation graph for backprop when computing accuracy
    model.eval()
    with torch.set_grad_enabled(False):
        train_acc, train_loss = compute_accuracy_and_loss(model, train_loader, device=DEVICE)
        test_acc, test_loss = compute_accuracy_and_loss(model, test_loader, device=DEVICE)
        train_acc_lst.append(train_acc)
        test_acc_lst.append(test_acc)
        train_loss_lst.append(train_loss)
        test_loss_lst.append(test_loss)
        print(f'Epoch: {epoch+1:03d}/{NUM_EPOCHS:03d} Train Acc.: {train_acc:.2f}%'
              f' | Test Acc.: {test_acc:.2f}%')
        
    elapsed = (time.time() - start_time)/60
    print(f'Time elapsed: {elapsed:.2f} min')
  
elapsed = (time.time() - start_time)/60
print(f'Total Training Time: {elapsed:.2f} min')
# Out:
# Epoch: 001/030 | Batch 000/468 | Cost: 2.3054
# Epoch: 001/030 | Batch 040/468 | Cost: 0.8775
# Epoch: 001/030 | Batch 080/468 | Cost: 0.7258
# Epoch: 001/030 | Batch 120/468 | Cost: 0.7303
# Epoch: 001/030 | Batch 160/468 | Cost: 0.5767
# Epoch: 001/030 | Batch 200/468 | Cost: 0.5947
# Epoch: 001/030 | Batch 240/468 | Cost: 0.5868
# Epoch: 001/030 | Batch 280/468 | Cost: 0.3335
# Epoch: 001/030 | Batch 320/468 | Cost: 0.5210
# Epoch: 001/030 | Batch 360/468 | Cost: 0.6218
# Epoch: 001/030 | Batch 400/468 | Cost: 0.4564
# Epoch: 001/030 | Batch 440/468 | Cost: 0.4857
# Epoch: 001/030 Train Acc.: 76.43% | Test Acc.: 74.86%
# Time elapsed: 0.35 min
# Epoch: 002/030 | Batch 000/468 | Cost: 0.4980
# Epoch: 002/030 | Batch 040/468 | Cost: 0.4112
# Epoch: 002/030 | Batch 080/468 | Cost: 0.3221
# Epoch: 002/030 | Batch 120/468 | Cost: 0.4052
# Epoch: 002/030 | Batch 160/468 | Cost: 0.3969
# Epoch: 002/030 | Batch 200/468 | Cost: 0.4425
# Epoch: 002/030 | Batch 240/468 | Cost: 0.3359
# Epoch: 002/030 | Batch 280/468 | Cost: 0.3801
# Epoch: 002/030 | Batch 320/468 | Cost: 0.4104
# Epoch: 002/030 | Batch 360/468 | Cost: 0.3924
# Epoch: 002/030 | Batch 400/468 | Cost: 0.3257
# Epoch: 002/030 | Batch 440/468 | Cost: 0.4416
# Epoch: 002/030 Train Acc.: 86.35% | Test Acc.: 84.93%
# Time elapsed: 0.69 min
# Epoch: 003/030 | Batch 000/468 | Cost: 0.3680
# Epoch: 003/030 | Batch 040/468 | Cost: 0.3337
# Epoch: 003/030 | Batch 080/468 | Cost: 0.3690
# Epoch: 003/030 | Batch 120/468 | Cost: 0.4106
# Epoch: 003/030 | Batch 160/468 | Cost: 0.5485
# Epoch: 003/030 | Batch 200/468 | Cost: 0.3433
# Epoch: 003/030 | Batch 240/468 | Cost: 0.3512
# Epoch: 003/030 | Batch 280/468 | Cost: 0.3104
# Epoch: 003/030 | Batch 320/468 | Cost: 0.4513
# Epoch: 003/030 | Batch 360/468 | Cost: 0.3290
# Epoch: 003/030 | Batch 400/468 | Cost: 0.4613
# Epoch: 003/030 | Batch 440/468 | Cost: 0.3538
# Epoch: 003/030 Train Acc.: 87.82% | Test Acc.: 86.05%
# Time elapsed: 1.04 min
# Epoch: 004/030 | Batch 000/468 | Cost: 0.3826
# Epoch: 004/030 | Batch 040/468 | Cost: 0.4314
# Epoch: 004/030 | Batch 080/468 | Cost: 0.2530
# Epoch: 004/030 | Batch 120/468 | Cost: 0.3190
# Epoch: 004/030 | Batch 160/468 | Cost: 0.4820
# Epoch: 004/030 | Batch 200/468 | Cost: 0.4250
# Epoch: 004/030 | Batch 240/468 | Cost: 0.3659
# Epoch: 004/030 | Batch 280/468 | Cost: 0.4334
# Epoch: 004/030 | Batch 320/468 | Cost: 0.3007
# Epoch: 004/030 | Batch 360/468 | Cost: 0.3093
# Epoch: 004/030 | Batch 400/468 | Cost: 0.4146
# Epoch: 004/030 | Batch 440/468 | Cost: 0.4146
# Epoch: 004/030 Train Acc.: 87.08% | Test Acc.: 85.15%
# Time elapsed: 1.39 min
# Epoch: 005/030 | Batch 000/468 | Cost: 0.3270
# Epoch: 005/030 | Batch 040/468 | Cost: 0.2933
# Epoch: 005/030 | Batch 080/468 | Cost: 0.3823
# Epoch: 005/030 | Batch 120/468 | Cost: 0.3476
# Epoch: 005/030 | Batch 160/468 | Cost: 0.3097
# Epoch: 005/030 | Batch 200/468 | Cost: 0.2955
# Epoch: 005/030 | Batch 240/468 | Cost: 0.1833
# Epoch: 005/030 | Batch 280/468 | Cost: 0.2444
# Epoch: 005/030 | Batch 320/468 | Cost: 0.2873
# Epoch: 005/030 | Batch 360/468 | Cost: 0.3365
# Epoch: 005/030 | Batch 400/468 | Cost: 0.2718
# Epoch: 005/030 | Batch 440/468 | Cost: 0.2267
# Epoch: 005/030 Train Acc.: 88.20% | Test Acc.: 86.04%
# Time elapsed: 1.73 min
# Epoch: 006/030 | Batch 000/468 | Cost: 0.3360
# Epoch: 006/030 | Batch 040/468 | Cost: 0.3629
# Epoch: 006/030 | Batch 080/468 | Cost: 0.4274
# Epoch: 006/030 | Batch 120/468 | Cost: 0.2715
# Epoch: 006/030 | Batch 160/468 | Cost: 0.3849
# Epoch: 006/030 | Batch 200/468 | Cost: 0.2391
# Epoch: 006/030 | Batch 240/468 | Cost: 0.2758
# Epoch: 006/030 | Batch 280/468 | Cost: 0.2991
# Epoch: 006/030 | Batch 320/468 | Cost: 0.3401
# Epoch: 006/030 | Batch 360/468 | Cost: 0.2105
# Epoch: 006/030 | Batch 400/468 | Cost: 0.3888
# Epoch: 006/030 | Batch 440/468 | Cost: 0.2333
# Epoch: 006/030 Train Acc.: 89.67% | Test Acc.: 87.46%
# Time elapsed: 2.08 min
# Epoch: 007/030 | Batch 000/468 | Cost: 0.2878
# Epoch: 007/030 | Batch 040/468 | Cost: 0.3502
# Epoch: 007/030 | Batch 080/468 | Cost: 0.2507
# Epoch: 007/030 | Batch 120/468 | Cost: 0.3721
# Epoch: 007/030 | Batch 160/468 | Cost: 0.2257
# Epoch: 007/030 | Batch 200/468 | Cost: 0.3218
# Epoch: 007/030 | Batch 240/468 | Cost: 0.3465
# Epoch: 007/030 | Batch 280/468 | Cost: 0.3120
# Epoch: 007/030 | Batch 320/468 | Cost: 0.3127
# Epoch: 007/030 | Batch 360/468 | Cost: 0.2666
# Epoch: 007/030 | Batch 400/468 | Cost: 0.3533
# Epoch: 007/030 | Batch 440/468 | Cost: 0.2404
# Epoch: 007/030 Train Acc.: 89.76% | Test Acc.: 87.45%
# Time elapsed: 2.43 min
# Epoch: 008/030 | Batch 000/468 | Cost: 0.4012
# Epoch: 008/030 | Batch 040/468 | Cost: 0.1979
# Epoch: 008/030 | Batch 080/468 | Cost: 0.2399
# Epoch: 008/030 | Batch 120/468 | Cost: 0.3048
# Epoch: 008/030 | Batch 160/468 | Cost: 0.3363
# Epoch: 008/030 | Batch 200/468 | Cost: 0.2960
# Epoch: 008/030 | Batch 240/468 | Cost: 0.1905
# Epoch: 008/030 | Batch 280/468 | Cost: 0.3112
# Epoch: 008/030 | Batch 320/468 | Cost: 0.2583
# Epoch: 008/030 | Batch 360/468 | Cost: 0.2910
# Epoch: 008/030 | Batch 400/468 | Cost: 0.2803
# Epoch: 008/030 | Batch 440/468 | Cost: 0.2011
# Epoch: 008/030 Train Acc.: 90.73% | Test Acc.: 88.01%
# Time elapsed: 2.78 min
# Epoch: 009/030 | Batch 000/468 | Cost: 0.1967
# Epoch: 009/030 | Batch 040/468 | Cost: 0.2608
# Epoch: 009/030 | Batch 080/468 | Cost: 0.1975
# Epoch: 009/030 | Batch 120/468 | Cost: 0.3465
# Epoch: 009/030 | Batch 160/468 | Cost: 0.1856
# Epoch: 009/030 | Batch 200/468 | Cost: 0.1788
# Epoch: 009/030 | Batch 240/468 | Cost: 0.2844
# Epoch: 009/030 | Batch 280/468 | Cost: 0.2489
# Epoch: 009/030 | Batch 320/468 | Cost: 0.2999
# Epoch: 009/030 | Batch 360/468 | Cost: 0.2877
# Epoch: 009/030 | Batch 400/468 | Cost: 0.3207
# Epoch: 009/030 | Batch 440/468 | Cost: 0.3528
# Epoch: 009/030 Train Acc.: 89.99% | Test Acc.: 87.11%
# Time elapsed: 3.13 min
# Epoch: 010/030 | Batch 000/468 | Cost: 0.2419
# Epoch: 010/030 | Batch 040/468 | Cost: 0.3054
# Epoch: 010/030 | Batch 080/468 | Cost: 0.1689
# Epoch: 010/030 | Batch 120/468 | Cost: 0.1297
# Epoch: 010/030 | Batch 160/468 | Cost: 0.2114
# Epoch: 010/030 | Batch 200/468 | Cost: 0.2507
# Epoch: 010/030 | Batch 240/468 | Cost: 0.2739
# Epoch: 010/030 | Batch 280/468 | Cost: 0.3490
# Epoch: 010/030 | Batch 320/468 | Cost: 0.2767
# Epoch: 010/030 | Batch 360/468 | Cost: 0.2050
# Epoch: 010/030 | Batch 400/468 | Cost: 0.1506
# Epoch: 010/030 | Batch 440/468 | Cost: 0.2095
# Epoch: 010/030 Train Acc.: 90.75% | Test Acc.: 87.77%
# Time elapsed: 3.48 min
# Epoch: 011/030 | Batch 000/468 | Cost: 0.2391
# Epoch: 011/030 | Batch 040/468 | Cost: 0.2999
# Epoch: 011/030 | Batch 080/468 | Cost: 0.2982
# Epoch: 011/030 | Batch 120/468 | Cost: 0.2609
# Epoch: 011/030 | Batch 160/468 | Cost: 0.1800
# Epoch: 011/030 | Batch 200/468 | Cost: 0.1812
# Epoch: 011/030 | Batch 240/468 | Cost: 0.2800
# Epoch: 011/030 | Batch 280/468 | Cost: 0.2532
# Epoch: 011/030 | Batch 320/468 | Cost: 0.3657
# Epoch: 011/030 | Batch 360/468 | Cost: 0.2410
# Epoch: 011/030 | Batch 400/468 | Cost: 0.2259
# Epoch: 011/030 | Batch 440/468 | Cost: 0.3285
# Epoch: 011/030 Train Acc.: 91.76% | Test Acc.: 88.22%
# Time elapsed: 3.83 min
# Epoch: 012/030 | Batch 000/468 | Cost: 0.2554
# Epoch: 012/030 | Batch 040/468 | Cost: 0.2499
# Epoch: 012/030 | Batch 080/468 | Cost: 0.2764
# Epoch: 012/030 | Batch 120/468 | Cost: 0.2046
# Epoch: 012/030 | Batch 160/468 | Cost: 0.2141
# Epoch: 012/030 | Batch 200/468 | Cost: 0.3640
# Epoch: 012/030 | Batch 240/468 | Cost: 0.2754
# Epoch: 012/030 | Batch 280/468 | Cost: 0.2187
# Epoch: 012/030 | Batch 320/468 | Cost: 0.2825
# Epoch: 012/030 | Batch 360/468 | Cost: 0.2195
# Epoch: 012/030 | Batch 400/468 | Cost: 0.3172
# Epoch: 012/030 | Batch 440/468 | Cost: 0.3070
# Epoch: 012/030 Train Acc.: 91.91% | Test Acc.: 88.37%
# Time elapsed: 4.18 min
# Epoch: 013/030 | Batch 000/468 | Cost: 0.1779
# Epoch: 013/030 | Batch 040/468 | Cost: 0.2174
# Epoch: 013/030 | Batch 080/468 | Cost: 0.3107
# Epoch: 013/030 | Batch 120/468 | Cost: 0.2399
# Epoch: 013/030 | Batch 160/468 | Cost: 0.1993
# Epoch: 013/030 | Batch 200/468 | Cost: 0.1919
# Epoch: 013/030 | Batch 240/468 | Cost: 0.3249
# Epoch: 013/030 | Batch 280/468 | Cost: 0.2540
# Epoch: 013/030 | Batch 320/468 | Cost: 0.1997
# Epoch: 013/030 | Batch 360/468 | Cost: 0.1932
# Epoch: 013/030 | Batch 400/468 | Cost: 0.2212
# Epoch: 013/030 | Batch 440/468 | Cost: 0.1932
# Epoch: 013/030 Train Acc.: 92.15% | Test Acc.: 88.66%
# Time elapsed: 4.53 min
# Epoch: 014/030 | Batch 000/468 | Cost: 0.1674
# Epoch: 014/030 | Batch 040/468 | Cost: 0.1815
# Epoch: 014/030 | Batch 080/468 | Cost: 0.2474
# Epoch: 014/030 | Batch 120/468 | Cost: 0.1758
# Epoch: 014/030 | Batch 160/468 | Cost: 0.2556
# Epoch: 014/030 | Batch 200/468 | Cost: 0.3016
# Epoch: 014/030 | Batch 240/468 | Cost: 0.1277
# Epoch: 014/030 | Batch 280/468 | Cost: 0.1842
# Epoch: 014/030 | Batch 320/468 | Cost: 0.2766
# Epoch: 014/030 | Batch 360/468 | Cost: 0.2157
# Epoch: 014/030 | Batch 400/468 | Cost: 0.1873
# Epoch: 014/030 | Batch 440/468 | Cost: 0.2767
# Epoch: 014/030 Train Acc.: 91.91% | Test Acc.: 88.17%
# Time elapsed: 4.88 min
# Epoch: 015/030 | Batch 000/468 | Cost: 0.2393
# Epoch: 015/030 | Batch 040/468 | Cost: 0.2252
# Epoch: 015/030 | Batch 080/468 | Cost: 0.2098
# Epoch: 015/030 | Batch 120/468 | Cost: 0.2598
# Epoch: 015/030 | Batch 160/468 | Cost: 0.1281
# Epoch: 015/030 | Batch 200/468 | Cost: 0.1864
# Epoch: 015/030 | Batch 240/468 | Cost: 0.2993
# Epoch: 015/030 | Batch 280/468 | Cost: 0.1596
# Epoch: 015/030 | Batch 320/468 | Cost: 0.3837
# Epoch: 015/030 | Batch 360/468 | Cost: 0.2984
# Epoch: 015/030 | Batch 400/468 | Cost: 0.2440
# Epoch: 015/030 | Batch 440/468 | Cost: 0.2429
# Epoch: 015/030 Train Acc.: 91.51% | Test Acc.: 87.51%
# Time elapsed: 5.23 min
# Epoch: 016/030 | Batch 000/468 | Cost: 0.1506
# Epoch: 016/030 | Batch 040/468 | Cost: 0.1466
# Epoch: 016/030 | Batch 080/468 | Cost: 0.1321
# Epoch: 016/030 | Batch 120/468 | Cost: 0.2058
# Epoch: 016/030 | Batch 160/468 | Cost: 0.1879
# Epoch: 016/030 | Batch 200/468 | Cost: 0.1496
# Epoch: 016/030 | Batch 240/468 | Cost: 0.2978
# Epoch: 016/030 | Batch 280/468 | Cost: 0.1645
# Epoch: 016/030 | Batch 320/468 | Cost: 0.1591
# Epoch: 016/030 | Batch 360/468 | Cost: 0.2010
# Epoch: 016/030 | Batch 400/468 | Cost: 0.1490
# Epoch: 016/030 | Batch 440/468 | Cost: 0.1418
# Epoch: 016/030 Train Acc.: 92.97% | Test Acc.: 88.38%
# Time elapsed: 5.58 min
# Epoch: 017/030 | Batch 000/468 | Cost: 0.1960
# Epoch: 017/030 | Batch 040/468 | Cost: 0.3361
# Epoch: 017/030 | Batch 080/468 | Cost: 0.2217
# Epoch: 017/030 | Batch 120/468 | Cost: 0.2219
# Epoch: 017/030 | Batch 160/468 | Cost: 0.1542
# Epoch: 017/030 | Batch 200/468 | Cost: 0.1829
# Epoch: 017/030 | Batch 240/468 | Cost: 0.1401
# Epoch: 017/030 | Batch 280/468 | Cost: 0.1075
# Epoch: 017/030 | Batch 320/468 | Cost: 0.2776
# Epoch: 017/030 | Batch 360/468 | Cost: 0.1501
# Epoch: 017/030 | Batch 400/468 | Cost: 0.1539
# Epoch: 017/030 | Batch 440/468 | Cost: 0.1917
# Epoch: 017/030 Train Acc.: 91.41% | Test Acc.: 87.70%
# Time elapsed: 5.94 min
# Epoch: 018/030 | Batch 000/468 | Cost: 0.3032
# Epoch: 018/030 | Batch 040/468 | Cost: 0.1720
# Epoch: 018/030 | Batch 080/468 | Cost: 0.2086
# Epoch: 018/030 | Batch 120/468 | Cost: 0.1787
# Epoch: 018/030 | Batch 160/468 | Cost: 0.1697
# Epoch: 018/030 | Batch 200/468 | Cost: 0.1288
# Epoch: 018/030 | Batch 240/468 | Cost: 0.1424
# Epoch: 018/030 | Batch 280/468 | Cost: 0.1516
# Epoch: 018/030 | Batch 320/468 | Cost: 0.1294
# Epoch: 018/030 | Batch 360/468 | Cost: 0.3036
# Epoch: 018/030 | Batch 400/468 | Cost: 0.1942
# Epoch: 018/030 | Batch 440/468 | Cost: 0.2049
# Epoch: 018/030 Train Acc.: 93.66% | Test Acc.: 88.87%
# Time elapsed: 6.29 min
# Epoch: 019/030 | Batch 000/468 | Cost: 0.1416
# Epoch: 019/030 | Batch 040/468 | Cost: 0.2364
# Epoch: 019/030 | Batch 080/468 | Cost: 0.1251
# Epoch: 019/030 | Batch 120/468 | Cost: 0.2097
# Epoch: 019/030 | Batch 160/468 | Cost: 0.1905
# Epoch: 019/030 | Batch 200/468 | Cost: 0.2081
# Epoch: 019/030 | Batch 240/468 | Cost: 0.1815
# Epoch: 019/030 | Batch 280/468 | Cost: 0.2060
# Epoch: 019/030 | Batch 320/468 | Cost: 0.1841
# Epoch: 019/030 | Batch 360/468 | Cost: 0.1956
# Epoch: 019/030 | Batch 400/468 | Cost: 0.1549
# Epoch: 019/030 | Batch 440/468 | Cost: 0.1788
# Epoch: 019/030 Train Acc.: 93.17% | Test Acc.: 88.56%
# Time elapsed: 6.64 min
# Epoch: 020/030 | Batch 000/468 | Cost: 0.1133
# Epoch: 020/030 | Batch 040/468 | Cost: 0.1858
# Epoch: 020/030 | Batch 080/468 | Cost: 0.1906
# Epoch: 020/030 | Batch 120/468 | Cost: 0.2097
# Epoch: 020/030 | Batch 160/468 | Cost: 0.2006
# Epoch: 020/030 | Batch 200/468 | Cost: 0.1150
# Epoch: 020/030 | Batch 240/468 | Cost: 0.1841
# Epoch: 020/030 | Batch 280/468 | Cost: 0.1891
# Epoch: 020/030 | Batch 320/468 | Cost: 0.1661
# Epoch: 020/030 | Batch 360/468 | Cost: 0.1649
# Epoch: 020/030 | Batch 400/468 | Cost: 0.2597
# Epoch: 020/030 | Batch 440/468 | Cost: 0.1432
# Epoch: 020/030 Train Acc.: 94.21% | Test Acc.: 88.96%
# Time elapsed: 6.99 min
# Epoch: 021/030 | Batch 000/468 | Cost: 0.1590
# Epoch: 021/030 | Batch 040/468 | Cost: 0.1656
# Epoch: 021/030 | Batch 080/468 | Cost: 0.1808
# Epoch: 021/030 | Batch 120/468 | Cost: 0.1750
# Epoch: 021/030 | Batch 160/468 | Cost: 0.1142
# Epoch: 021/030 | Batch 200/468 | Cost: 0.1372
# Epoch: 021/030 | Batch 240/468 | Cost: 0.1634
# Epoch: 021/030 | Batch 280/468 | Cost: 0.2005
# Epoch: 021/030 | Batch 320/468 | Cost: 0.2533
# Epoch: 021/030 | Batch 360/468 | Cost: 0.1145
# Epoch: 021/030 | Batch 400/468 | Cost: 0.1741
# Epoch: 021/030 | Batch 440/468 | Cost: 0.1716
# Epoch: 021/030 Train Acc.: 94.34% | Test Acc.: 88.73%
# Time elapsed: 7.35 min
# Epoch: 022/030 | Batch 000/468 | Cost: 0.1758
# Epoch: 022/030 | Batch 040/468 | Cost: 0.1797
# Epoch: 022/030 | Batch 080/468 | Cost: 0.1483
# Epoch: 022/030 | Batch 120/468 | Cost: 0.1924
# Epoch: 022/030 | Batch 160/468 | Cost: 0.1237
# Epoch: 022/030 | Batch 200/468 | Cost: 0.1745
# Epoch: 022/030 | Batch 240/468 | Cost: 0.1252
# Epoch: 022/030 | Batch 280/468 | Cost: 0.2017
# Epoch: 022/030 | Batch 320/468 | Cost: 0.2425
# Epoch: 022/030 | Batch 360/468 | Cost: 0.1417
# Epoch: 022/030 | Batch 400/468 | Cost: 0.1563
# Epoch: 022/030 | Batch 440/468 | Cost: 0.1385
# Epoch: 022/030 Train Acc.: 93.57% | Test Acc.: 88.23%
# Time elapsed: 7.70 min
# Epoch: 023/030 | Batch 000/468 | Cost: 0.1398
# Epoch: 023/030 | Batch 040/468 | Cost: 0.2632
# Epoch: 023/030 | Batch 080/468 | Cost: 0.1792
# Epoch: 023/030 | Batch 120/468 | Cost: 0.1435
# Epoch: 023/030 | Batch 160/468 | Cost: 0.0829
# Epoch: 023/030 | Batch 200/468 | Cost: 0.1186
# Epoch: 023/030 | Batch 240/468 | Cost: 0.1180
# Epoch: 023/030 | Batch 280/468 | Cost: 0.1641
# Epoch: 023/030 | Batch 320/468 | Cost: 0.2335
# Epoch: 023/030 | Batch 360/468 | Cost: 0.0945
# Epoch: 023/030 | Batch 400/468 | Cost: 0.1886
# Epoch: 023/030 | Batch 440/468 | Cost: 0.1341
# Epoch: 023/030 Train Acc.: 94.77% | Test Acc.: 88.98%
# Time elapsed: 8.05 min
# Epoch: 024/030 | Batch 000/468 | Cost: 0.0910
# Epoch: 024/030 | Batch 040/468 | Cost: 0.1820
# Epoch: 024/030 | Batch 080/468 | Cost: 0.1854
# Epoch: 024/030 | Batch 120/468 | Cost: 0.0741
# Epoch: 024/030 | Batch 160/468 | Cost: 0.1863
# Epoch: 024/030 | Batch 200/468 | Cost: 0.1626
# Epoch: 024/030 | Batch 240/468 | Cost: 0.0658
# Epoch: 024/030 | Batch 280/468 | Cost: 0.1488
# Epoch: 024/030 | Batch 320/468 | Cost: 0.1194
# Epoch: 024/030 | Batch 360/468 | Cost: 0.0933
# Epoch: 024/030 | Batch 400/468 | Cost: 0.2196
# Epoch: 024/030 | Batch 440/468 | Cost: 0.0969
# Epoch: 024/030 Train Acc.: 94.95% | Test Acc.: 88.99%
# Time elapsed: 8.40 min
# Epoch: 025/030 | Batch 000/468 | Cost: 0.1822
# Epoch: 025/030 | Batch 040/468 | Cost: 0.1390
# Epoch: 025/030 | Batch 080/468 | Cost: 0.2054
# Epoch: 025/030 | Batch 120/468 | Cost: 0.1085
# Epoch: 025/030 | Batch 160/468 | Cost: 0.2497
# Epoch: 025/030 | Batch 200/468 | Cost: 0.1242
# Epoch: 025/030 | Batch 240/468 | Cost: 0.1240
# Epoch: 025/030 | Batch 280/468 | Cost: 0.1505
# Epoch: 025/030 | Batch 320/468 | Cost: 0.1937
# Epoch: 025/030 | Batch 360/468 | Cost: 0.1417
# Epoch: 025/030 | Batch 400/468 | Cost: 0.1275
# Epoch: 025/030 | Batch 440/468 | Cost: 0.1271
# Epoch: 025/030 Train Acc.: 94.98% | Test Acc.: 89.06%
# Time elapsed: 8.75 min
# Epoch: 026/030 | Batch 000/468 | Cost: 0.1683
# Epoch: 026/030 | Batch 040/468 | Cost: 0.1577
# Epoch: 026/030 | Batch 080/468 | Cost: 0.1243
# Epoch: 026/030 | Batch 120/468 | Cost: 0.0861
# Epoch: 026/030 | Batch 160/468 | Cost: 0.1779
# Epoch: 026/030 | Batch 200/468 | Cost: 0.0796
# Epoch: 026/030 | Batch 240/468 | Cost: 0.1077
# Epoch: 026/030 | Batch 280/468 | Cost: 0.1416
# Epoch: 026/030 | Batch 320/468 | Cost: 0.0983
# Epoch: 026/030 | Batch 360/468 | Cost: 0.2205
# Epoch: 026/030 | Batch 400/468 | Cost: 0.0989
# Epoch: 026/030 | Batch 440/468 | Cost: 0.1431
# Epoch: 026/030 Train Acc.: 95.37% | Test Acc.: 89.26%
# Time elapsed: 9.10 min
# Epoch: 027/030 | Batch 000/468 | Cost: 0.1301
# Epoch: 027/030 | Batch 040/468 | Cost: 0.1123
# Epoch: 027/030 | Batch 080/468 | Cost: 0.1197
# Epoch: 027/030 | Batch 120/468 | Cost: 0.1860
# Epoch: 027/030 | Batch 160/468 | Cost: 0.1333
# Epoch: 027/030 | Batch 200/468 | Cost: 0.1384
# Epoch: 027/030 | Batch 240/468 | Cost: 0.1061
# Epoch: 027/030 | Batch 280/468 | Cost: 0.1101
# Epoch: 027/030 | Batch 320/468 | Cost: 0.0904
# Epoch: 027/030 | Batch 360/468 | Cost: 0.1497
# Epoch: 027/030 | Batch 400/468 | Cost: 0.1391
# Epoch: 027/030 | Batch 440/468 | Cost: 0.1605
# Epoch: 027/030 Train Acc.: 95.10% | Test Acc.: 88.81%
# Time elapsed: 9.45 min
# Epoch: 028/030 | Batch 000/468 | Cost: 0.1826
# Epoch: 028/030 | Batch 040/468 | Cost: 0.1526
# Epoch: 028/030 | Batch 080/468 | Cost: 0.0979
# Epoch: 028/030 | Batch 120/468 | Cost: 0.1522
# Epoch: 028/030 | Batch 160/468 | Cost: 0.2099
# Epoch: 028/030 | Batch 200/468 | Cost: 0.0983
# Epoch: 028/030 | Batch 240/468 | Cost: 0.1737
# Epoch: 028/030 | Batch 280/468 | Cost: 0.1469
# Epoch: 028/030 | Batch 320/468 | Cost: 0.1213
# Epoch: 028/030 | Batch 360/468 | Cost: 0.1281
# Epoch: 028/030 | Batch 400/468 | Cost: 0.1111
# Epoch: 028/030 | Batch 440/468 | Cost: 0.0783
# Epoch: 028/030 Train Acc.: 95.51% | Test Acc.: 88.77%
# Time elapsed: 9.81 min
# Epoch: 029/030 | Batch 000/468 | Cost: 0.1520
# Epoch: 029/030 | Batch 040/468 | Cost: 0.0770
# Epoch: 029/030 | Batch 080/468 | Cost: 0.1731
# Epoch: 029/030 | Batch 120/468 | Cost: 0.1431
# Epoch: 029/030 | Batch 160/468 | Cost: 0.1591
# Epoch: 029/030 | Batch 200/468 | Cost: 0.2030
# Epoch: 029/030 | Batch 240/468 | Cost: 0.2477
# Epoch: 029/030 | Batch 280/468 | Cost: 0.0860
# Epoch: 029/030 | Batch 320/468 | Cost: 0.0667
# Epoch: 029/030 | Batch 360/468 | Cost: 0.1930
# Epoch: 029/030 | Batch 400/468 | Cost: 0.0949
# Epoch: 029/030 | Batch 440/468 | Cost: 0.1435
# Epoch: 029/030 Train Acc.: 93.85% | Test Acc.: 88.06%
# Time elapsed: 10.17 min
# Epoch: 030/030 | Batch 000/468 | Cost: 0.2399
# Epoch: 030/030 | Batch 040/468 | Cost: 0.0814
# Epoch: 030/030 | Batch 080/468 | Cost: 0.0782
# Epoch: 030/030 | Batch 120/468 | Cost: 0.0639
# Epoch: 030/030 | Batch 160/468 | Cost: 0.0962
# Epoch: 030/030 | Batch 200/468 | Cost: 0.1227
# Epoch: 030/030 | Batch 240/468 | Cost: 0.0981
# Epoch: 030/030 | Batch 280/468 | Cost: 0.0917
# Epoch: 030/030 | Batch 320/468 | Cost: 0.1482
# Epoch: 030/030 | Batch 360/468 | Cost: 0.1167
# Epoch: 030/030 | Batch 400/468 | Cost: 0.0940
# Epoch: 030/030 | Batch 440/468 | Cost: 0.1937
# Epoch: 030/030 Train Acc.: 95.59% | Test Acc.: 88.95%
# Time elapsed: 10.52 min
# Total Training Time: 10.52 min

# %% [markdown]
# ## 5) Evaluation
#
# 테스트 데이터와 학습 데이터의 Loss변화를 확인합니다.

# %%
plt.plot(range(1, NUM_EPOCHS+1), train_loss_lst, label='Training loss')
plt.plot(range(1, NUM_EPOCHS+1), test_loss_lst, label='Test loss')
plt.legend(loc='upper right')
plt.ylabel('Cross entropy')
plt.xlabel('Epoch')
plt.show()

# %%
plt.plot(range(1, NUM_EPOCHS+1), train_acc_lst, label='Training accuracy')
plt.plot(range(1, NUM_EPOCHS+1), test_acc_lst, label='Test accuracy')
plt.legend(loc='upper left')
plt.ylabel('Cross entropy')
plt.xlabel('Epoch')
plt.show()

# %%
model.eval()
with torch.set_grad_enabled(False): # save memory during inference
    test_acc, test_loss = compute_accuracy_and_loss(model, test_loader, DEVICE)
    print(f'Test accuracy: {test_acc:.2f}%')
# Out:
# Test accuracy: 88.95%

# %% [markdown]
# ## 6) Discussion (2점)

# %% [markdown]
# **1) 학습, 테스트 정확도는 얼마인가요? (위 숫자를 복사하세요.)**

# %% [markdown]
# - Training : 95.59%
# - Test : 88.95%

# %% [markdown]
# **2) overfitting을 경험했나요? 만약 그랬다면 왜 그랬을지 적어보고, overfitting을 방지하기위한 간단한 방법은 무엇일까요?**

# %% [markdown]
# [제안하는 방법 적기]
#
# 과적합이 발생했을 때의 원인을 생각해보면 epoch의 원인이 컸다고 할 수 있다. epoch를 크게 가져갈수록 학습을 진행하는 횟수가 늘어나기 때문에 training 데이터에는 정확도가 많이 올라가는 반면 test 데이터에는 오히려 정확도가 떨어지는 모습을 보였다.
# 이를 방지하기 위해 epoch를 줄이고 줄어든 epoch 만큼 수렴 속도를 높이기 위해 batch size 를 키우고, hidden layer의 뉴런수도 늘려준다.
# - epoch = 30 으로 설정하고
# - batch size = 128 로 변경하고
# - hidden layer1,2의 뉴런 수 = 512 로 변경한다.

# %% [markdown]
# **3) 만약 hidden layer 수가 늘어나면(3개 이상) 얻을 수 있는 장/단점은 무엇일까요?**

# %% [markdown]
# [답변작성]
#
# hidden layer가 늘어나면 비선형이고 다차원적인 결정경계를 통해 학습을 할 수 있기 때문에 복잡한 데이터에 대해 정밀하게 학습이 가능하다는 장점이 있다.
# 하지만 그에 반해 단점도 있다. hidden layer가 늘어나면 발생할 수 있는 문제는 첫번째로 과적합 문제가 있다. 은닉층이 늘어난다는 것은 장점에서도 이야기 했듯 훈련을 더 잘 시킬 수 있다는 것인데, 이것은 곧 훈련 데이터에 과도하게 적합하게 되어 막상 테스트 데이터에서는 성능이 나빠지는 결과를 초래할 수 있다. 또한 출력층의 오차가 은닉층으로 역전파되어 학습이 되어야하는데 은닉층이 많아지게 되어 출력층에서 매우 먼 은닉층이 존재하게 될 경우, 출력오차가 은닉층에 반영이 되지 않는 현상이 발생할 수 있다. 이를 그래디언트 소실이라고 부른다.

# %% [markdown]
# **4) 구현하면서 수정한 부분에 대해 작성하여 수정한 이유 및 성능향상이 생긴 이유에 대해 답해보세요.**

# %% [markdown]
# [답변작성]
#
# 가장 먼저 epoch를 10으로 하고 활성함수는 sigmoid 함수를 사용하여 학습을 진행했는데, 이때는 85%를 넘지 못했다. 그래서 epoch를 50으로 두어 학습을 조금 더 여러번 시키면 정확도가 올라가지 않을까 싶었지만 이때 또한 86%를 넘지 못했다. 따라서 활성함수를 Relu와 Leaky_Relu로 바꾸어 진행했을때 또한 정확도가 86%를 넘지 못하고 epoch가 30을 넘어가면 유의미한 변화 없이 그 사이를 왔다갔다하며 횡보하는 모습을 보였다. 따라서 이번에는 은닉층의 개수를 늘려주었는데 이랬을때는 오히려 epoch가 40을 넘어가면 84% 밑으로 떨어지는 모습을 보였다. 이를통해 은닉층의 개수는 2개가 적당하다고 생각했다.
# 그래서 epoch=30, activation_func = ReLu, hidden layer 개수 = 2개 까지는 고정으로 놓았다. 그리고 은닉층의 뉴런수를 늘려주었더니 초반에 정확도가 빠르게 높아지는 것을 확인할 수 있었고, 또한 늘려주기 이전보다 더 높은 정확도를 보여주는 것도 확인할 수 있었다. 그 이유를 추론해보면 은닉층 내 노드수를 늘리면 모델의 용량이 증가하게 되는데 이를 통해 입력 데이터의 미세한 세부사항을 더 잘 포작할 가능성이 높아셔 정확도 향상을 가져오기 때문이 아닐까 생각한다.
